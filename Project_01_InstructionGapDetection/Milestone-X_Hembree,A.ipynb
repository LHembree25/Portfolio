# %% [markdown]
# ### DSC 670 - Advanced Uses of Generative AI
# ### Milestone 2
# ### Hembree, Lex

# %% [markdown]
# This appendix contains the Jupyter Notebook used to run the five prompt experiments for Milestone 2. The notebook includes the full prompt text, the model outputs, and my commentary on each result. The purpose of this appendix is to document how the model behaved under each prompt and to evaluate whether prompting alone is sufficient for detecting instruction gaps. The commentary focuses on the clarity, consistency, and domain awareness shown in the outputs, and whether the model required additional training to perform the task.

# %%
# Import library
import os
from openai import OpenAI

# Set API key
os.environ["OPENAI_API_KEY"] = "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"

# build openai prompt
client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])

prompt = """
Identify unclear or incomplete steps in the following instructions.
Explain why a novice would struggle.

Flat tires are one of the most usual repairs that you may need to do because on
the road itself, there are many things that will cause your tyres to burst.

(0) Stop at the road side and put a triangular warning sign to warn cars about stopping.
(1) Locate spare tyres (usually in the car butt bonnet), and make sure that it is inflated.
(2) Engage parking break and vehicle is in Parking Gear (Auto) or in Neutral Gear (Manual).
(3) Use tire wrench to loosen lug nuts.
(4) Jack off car until tire finishes on ground.
(5) Remove lug nuts.
(6) Remove deflated tire.
(7) Replace with spare tyres.
(8) Tighten lug nuts.
(9) Release jack until tire touches ground.
"""

resp = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": prompt}]
)

print(resp.choices[0].message.content)
# Out:
# There are several unclear or incomplete steps in the provided instructions for changing a flat tire, which a novice might struggle with:
#
# 1. **Step 1: "Locate spare tyres (usually in the car butt bonnet), and make sure that it is inflated."**
#    - **Unclear**: The term "car butt bonnet" is confusing. It’s unclear whether this refers to the trunk or the front hood of the car (where the engine is). A novice might not know where to look for the spare tire. Additionally, the instruction to ensure the tire is inflated lacks specifics on how to check the inflation pressure.
#
# 2. **Step 4: "Jack off car until tire finishes on ground."**
#    - **Incomplete**: The phrasing “until tire finishes on ground” is confusing and likely a typo. It should specify that the tire should be off the ground in order to remove it. Novices may not understand how high to raise the car nor how the jack should be placed to achieve this.
#
# 3. **Step 8: "Tighten lug nuts."**
#    - **Incomplete**: There should be a mention of the proper method for tightening lug nuts (e.g., using a star pattern) to ensure that they are secure. Novices might accidentally cross-thread the lug nuts or fail to tighten them sufficiently.
#
# 4. **Step 9: "Release jack until tire touches ground."**
#    - **Unclear**: The step should clarify that the car should be lowered slowly and that the lug nuts should be tightened (mentioning any specific order or torque specifications) before lowering the car fully. Without this knowledge, they could improperly secure the tire, creating a safety hazard.
#
# Overall, a novice might struggle with vocabulary, incomplete instructions, and a lack of detailed guidance on proper techniques, which are crucial for safely and effectively changing a tire.

# %% [markdown]
# #### Experiment 1 Commentary – Direct Gap Detection (Flat Tire)
# The model identified unclear terminology, missing safety steps, and ambiguous phrasing. These are legitimate gaps in the Wikibooks instructions. The model did not hallucinate or skip critical steps. The output shows the model can detect procedural ambiguity without additional training. This confirms that prompt‑based gap detection works for basic automotive tasks.

# %%
# Import library
import os
from openai import OpenAI

# Set API key
os.environ["OPENAI_API_KEY"] = "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"

# build openai prompt
client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])

prompt = """
Identify unclear or incomplete steps in the following instructions.
Explain why a novice would struggle.

Step-by-Step Instructions:

1. Tie a knot in one end of one of the laces just above the tip. Match up the diamond holes in the sole and toe plug, with the other end of the lace, sew from the outside of the sole up though the toe plug. After pulling the knot tight pass the lace back through the diamond hole in the sole only. Your lace should have looped the two pieces of leather together and be in between the sole and toe plug.
2. Now pass the lace on the inside of your moccasin through the next hole in the sole and pull tight to form a pucker between the stitches. Hold the leather in place with your thumb and sew through the next hole in the toe plug from the outside and pull your stitch tight. Continue around the entire toe passing the lace out through the sole and down through the toe plug, pulling each stitch tight, until you reach the next set of diamond holes.
3. Stitch through diamond holes twice, ending back on the outside of the sole. Tie the lace in a knot as close to the leather as possible. Trim off any excess lace.
4. Cut one lace in half and use to assemble moccasin heels. Fold the ends of the sole around as shown and match up the appropriate set of holes. Then fold the heel flap up over the back of the moccasin.

NOTE: Each moccasin kit is designed to fit two shoe sizes. Depending on the size that will best fit you will determine how you will assemble the heel of the moccasin. The XS kit will make a 4/5, the S will make a 6/7, the M an 8/9 and the L will make a 10/11. To make the smaller of the sizes for the kit, match up the round holes on either side of the moccasin heel. Or, to make the larger size for your kit you will need to match up diamond holes on either side of the moccasin heel. 
Starting with the upper right side hole, lace through to the inside of the mock then down to the left side lower hole. Lace through to the back by going through the right side lower hole and back out of the remaining upper hole. Once completed, the lacing should have an "X" on the inside as in the picture below. Then tie the loose ends in a square knot and trim off the excess lace. 

5. Leaving about 6” of lace, go down through the left center hole in the toe plug, then out through the next hole. Begin lacing by folding the cuff over the edge of the moccasin sole and lining up the holes. Lace in and out through all three layers of leather in a running stitch. When you reach the heel of the moccasin, overlap 4 holes for smaller sizes and 3 holes for the large sizes.
6. Continue running stitch all the way around the moccasin and finish by threading the lace out through the toe plug as you started and evening up the lace ends. Tie the laces in a bow and your moccasin is complete!

NOTE: If making the smaller of the two sizes available for your kit you may need to cut off an extra set of holes from one end of the cuff after attaching. Larger moccasin sizes should use the cuff “as is.”
"""

resp = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": prompt}]
)

print(resp.choices[0].message.content)
# Out:
# The provided instructions include several unclear or incomplete steps that would pose challenges for a novice. Here are the identified issues along with explanations of why a beginner would struggle with them:
#
# ### Unclear or Incomplete Steps:
#
# 1. **Step 1:**
#    - **Issue:** The phrase "pass the lace back through the diamond hole in the sole only" may confuse someone unfamiliar with lace anatomy or terminology. The term "diamond hole" is not clearly defined within the instructions.
#    - **Explanation:** A novice may not know how to identify a "diamond hole" versus other holes or may have difficulty visualizing how to handle the lace after sewing it through the toe plug without a diagram.
#
# 2. **Step 2:**
#    - **Issue:** The instruction to "hold the leather in place with your thumb" lacks specificity on what exactly should be held. Additionally, there is no clarification on how tight is considered "tight" or how to create a "pucker" with the stitches.
#    - **Explanation:** A beginner may not visualize the proper holding technique or the desired outcome of the pucker, which can lead to inconsistencies in tension and stitching.
#
# 3. **Step 3:**
#    - **Issue:** The instruction to "stitch through diamond holes twice" does not specify which diamond holes to use or the method of stitching (for example, whether to go inside out, outside in, or follow a specific pattern).
#    - **Explanation:** Novices may become confused by the ambiguity of which direction to stitch and which holes to stitch through, potentially leading them to make mistakes in assembly.
#
# 4. **Step 4:**
#    - **Issue:** The explanation of how to "match up the appropriate set of holes" is vague without accompanying visuals to clarify specific patterns or configurations. The heel assembly instructions also lack specificity about the orientation of the pieces.
#    - **Explanation:** This vagueness could cause beginners to misalign holes or not understand how to position the sole and heel properly.
#
# 5. **Step 5:**
#    - **Issue:** The step discusses folding the cuff over the edge of the moccasin without a clear depiction of the cuff's starting position or how to align the holes properly.
#    - **Explanation:** Without visual aids or more detailed descriptions, novices may not correctly align all three layers of leather, resulting in issues with fit and appearance.
#
# 6. **Step 6:**
#    - **Issue:** The instruction to "evening up the lace ends" lacks a clear explanation of how this should be done, and it assumes that the reader knows how to tie a bow proficiently.
#    - **Explanation:** Beginners may struggle with tying bows or not understand how to ensure that the lace ends are of equal length while achieving a neat finish.
#
# 7. **General Notes:**
#    - **Issue:** The additional note comparing smaller and larger sizes assumes knowledge about adjusting patterns based on size without further instruction on how to do it practically. A person may not know about cutting holes or adjusting cuffs based solely on size information.
#    - **Explanation:** Novices may be unsure about how to implement size alterations without a hands-on guide or visuals demonstrating these adjustments.
#
# ### Conclusion:
# Overall, these instructions may leave a novice feeling overwhelmed or confused due to the lack of precise definitions, visual aids, and specifics about assembly techniques. Providing step-by-step illustrations, clearer terminology, and recommended practices for checking tension and alignment could significantly improve comprehension for someone unfamiliar with this type of task.

# %% [markdown]
# #### Experiment 2 Commentary – Direct Gap Detection (Moccasin Kit)
# The model identified stitching ambiguity, unclear hole alignment, and missing tension guidance. These are real gaps in the moccasin instructions. The model handled domain‑specific terminology without confusion. The output shows the model can detect gaps in craft instructions that rely on tacit knowledge. Prompt‑based detection works across domains.

# %%
# Import library
import os
from openai import OpenAI

# Set API key
os.environ["OPENAI_API_KEY"] = "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"

# build openai prompt
client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])

prompt = """
Evaluate each step in the following instructions for clarity, completeness, and assumptions.
Output a table with columns: step_number, issue_detected, severity, recommended_fix.

Instructions:

Flat tires are one of the most usual repairs that you may need to do because on
the road itself, there are many things that will cause your tyres to burst.

It would be wise to have this on the car before facing this problem.

(0) Stop at the road side and put a triangular warning sign to warn cars about stopping.
(1) Locate spare tyres (usually in the car butt bonnet), and make sure that it is inflated.
(2) Engage parking break and vehicle is in Parking Gear (Auto) or in Neutral Gear (Manual).
(3) Use tire wrench to loosen lug nuts.
(4) Jack off car until tire finishes on ground.
(5) Remove lug nuts.
(6) Remove deflated tire.
(7) Replace with spare tyres.
(8) Tighten lug nuts.
(9) Release jack until tire touches ground.
"""

resp = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": prompt}]
)

print(resp.choices[0].message.content)
# Out:
# Here is the evaluation of each step in the provided instructions regarding changing a flat tire:
#
# | step_number | issue_detected                                             | severity      | recommended_fix                                               |
# |-------------|-----------------------------------------------------------|---------------|--------------------------------------------------------------|
# | 0           | No mention of safety protocol, such as turning on hazard lights. | Major         | Add instruction to turn on hazard lights before stopping.    |
# | 1           | Incorrect location specified: "car butt bonnet" is unclear or wrong terminology. | Major         | Clarify location; likely meant "trunk" or "boot".            |
# | 2           | Not enough emphasis on ensuring the vehicle is on level ground before engaging parking brake. | Moderate      | Specify that vehicle should be on a flat, stable surface before engaging parking brake. |
# | 3           | Missing the instruction to use the correct sequence of loosening lug nuts (i.e., star pattern). | Moderate      | Advise loosening lug nuts in a star pattern to prevent wheel warping. |
# | 4           | Phrase "Jack off car" is unclear; possibly considered informal/incorrect language. | Moderate      | Change to "Raise the car with the jack until the tire is off the ground." |
# | 5           | Fails to mention that lug nuts should be fully removed and stored safely. | Minor         | Add instruction to store removed lug nuts in a safe place.    |
# | 6           | No instruction to check for safety or ensure no debris near wheel area before removal. | Moderate      | Suggest checking for any debris or obstacles before removing tire. |
# | 7           | No specification on ensuring the spare tire is the correct size/type for the vehicle. | Major         | Confirm that the spare tire is compatible with the vehicle before replacement. |
# | 8           | Missing step to ensure lug nuts are tightened in a star pattern again for safety. | Major         | Reinforce the instruction to tighten lug nuts in a star pattern for even tightness. |
# | 9           | Not clear about ensuring the jack is fully released and that the tire is secured before driving. | Moderate      | Add instruction to ensure lug nuts are secure before lowering the vehicle fully. |
#
# Overall, the instructions could benefit from precise language, safety precautions, and clarity to ensure a smooth process for users changing a flat tire.

# %% [markdown]
# #### Experiment 3 Commentary – Step‑by‑Step Gap Audit (Flat Tire)
# The model produced a structured table with step numbers, issues, severity, and recommended fixes. The issues identified match real procedural gaps: missing safety checks, unclear jack placement, missing lug‑nut sequence, and incomplete final steps. The model maintained consistency across all steps. This confirms that structured prompting is effective for systematic gap audits.

# %%
# Import library
import os
from openai import OpenAI

# Set API key
os.environ["OPENAI_API_KEY"] = "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"

# build openai prompt
client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])

prompt = """
Identify domain-specific gaps in the following moccasin assembly instructions.
Focus on missing tool requirements, skipped alignment steps, unclear stitching transitions,
and any assumptions a beginner would not know.

Instructions:

1. Tie a knot in one end of one of the laces just above the tip. Match up the diamond holes
in the sole and toe plug, with the other end of the lace, sew from the outside of the sole
up through the toe plug. After pulling the knot tight pass the lace back through the diamond
hole in the sole only. Your lace should have looped the two pieces of leather together and be
in between the sole and toe plug.

2. Now pass the lace on the inside of your moccasin through the next hole in the sole and pull
tight to form a pucker between the stitches. Hold the leather in place with your thumb and sew
through the next hole in the toe plug from the outside and pull your stitch tight. Continue
around the entire toe passing the lace out through the sole and down through the toe plug,
pulling each stitch tight, until you reach the next set of diamond holes.

3. Stitch through diamond holes twice, ending back on the outside of the sole. Tie the lace in
a knot as close to the leather as possible. Trim off any excess lace.

4. Cut one lace in half and use to assemble moccasin heels. Fold the ends of the sole around as
shown and match up the appropriate set of holes. Then fold the heel flap up over the back of
the moccasin.

NOTE: Each moccasin kit is designed to fit two shoe sizes. Depending on the size that will best
fit you will determine how you will assemble the heel of the moccasin. The XS kit will make a
4/5, the S will make a 6/7, the M an 8/9 and the L will make a 10/11. To make the smaller of the
sizes for the kit, match up the round holes on either side of the moccasin heel. Or, to make the
larger size for your kit you will need to match up diamond holes on either side of the moccasin heel.

Starting with the upper right side hole, lace through to the inside of the moccasin then down to
the left side lower hole. Lace through to the back by going through the right side lower hole and
back out of the remaining upper hole. Once completed, the lacing should have an "X" on the inside.
Then tie the loose ends in a square knot and trim off the excess lace.

5. Leaving about 6" of lace, go down through the left center hole in the toe plug, then out through
the next hole. Begin lacing by folding the cuff over the edge of the moccasin sole and lining up
the holes. Lace in and out through all three layers of leather in a running stitch. When you reach
the wheel of the moccasin, overlap 4 holes for smaller sizes and 3 holes for the larger sizes.

6. Continue running stitch all the way around the moccasin and finish by threading the lace out
through the toe plug as you started and evening up the lace ends. Tie the laces in a bow and your
moccasin is complete.
"""

resp = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": prompt}]
)

print(resp.choices[0].message.content)
# Out:
# The moccasin assembly instructions provided have several areas that could lead to confusion, particularly for beginners. Below is an identification of gaps and missing elements related to required tools, skipped alignment steps, unclear transitions in stitching, and assumptions:
#
# ### Missing Tool Requirements
# 1. **Needle Specification**: Instructions lack mention of what type of needle to use (e.g., leather needle vs. regular sewing needle). Specifying a blunt-tipped leather needle would help prevent damage to the materials.
# 2. **Awl**: The use of an awl for making holes may be necessary, especially if pre-punched holes are not present or if the fabric is too tough to pierce with lace alone.
# 3. **Cutting Tools**: Tools for trimming excess lace (e.g., scissors) should be explicitly mentioned, along with any requirements for the lace material (e.g., waxed vs. unwaxed lace).
# 4. **Measuring Tools**: A ruler or measuring tape could be suggested, especially when cutting the lace or ensuring proper fitting of the moccasins.
#
# ### Skipped Alignment Steps
# 1. **Initial Assembly Check**: A step prompting the assembler to lay out all components (sole, toe plug, heel, and laces) before starting could avoid confusion. Noting the positions of components might prevent incorrect assembly.
# 2. **Lace Length Calculation**: There is no guidance on how much lace to use for certain sizes, nor a recommendation on how to measure and cut the lace before beginning assembly.
# 3. **Heel Alignment Guidance**: Specific instructions on how to ensure that the heel is positioned before securing it to the sole are absent. Mentioning a visual orientation might help beginners correctly align the heel.
#
# ### Unclear Stitching Transitions
# 1. **Transition between Steps**: The instructions jump from one step to another without clear transitions, especially between sewing the toe and transitioning into the heel assembly. Explicitly stating when to change the focus from one area to another would help.
# 2. **Pucker Stringency**: The instructions mention creating a pucker but do not clarify how much tension to apply when pulling the stitches tight. Details about the desired look and feel of the stitches relative to one another would be beneficial.
# 3. **Running Stitch Clarification**: The term “running stitch” may not be clear to beginners. Including a brief description or diagram of the running stitch technique could alleviate confusion regarding how to execute it correctly.
#
# ### Assumptions About Experience Level
# 1. **Prior Knowledge**: The instructions assume familiarity with sewing techniques, specifically the types of knots used (e.g., square knot), and may not explain terms that a beginner might not understand, such as the difference between "diamond holes" and "round holes."
# 2. **Loop Importance**: The significance of the lace loop in Step 1 is not sufficiently emphasized, potentially leading to misunderstandings about the fundamental structure.
# 3. **Finishing the Moccasin**: The way to tie off the lace effectively after finishing the final stitch assumes prior knowledge of bow tying, which may not apply to all beginners.
#
# ### Suggested Improvements
# - **Include Visuals**: Adding diagrams or pictures to demonstrate each step could tremendously help beginners grasp the instructions better. Visual aids for lace patterns, the finished stitch, and how the pieces are oriented during assembly would clarify many ambiguous segments.
# - **Step-by-Step Breakdowns**: Breaking down each instruction into smaller sub-steps (e.g., "first, lace through hole A, then hole B") could make following the instructions less overwhelming.
# - **Add Troubleshooting Tips**: Suggestions on what to do if the lace is too short or if the stitches appear uneven could provide a safety net for novice assemblers.
#
# Incorporating these elements could significantly improve the clarity and usability of the moccasin assembly instructions for beginners.

# %% [markdown]
# #### Experiment 4 Commentary – Domain‑Specific Ambiguity Detection (Moccasin Kit)
# The model identified missing tool requirements, skipped alignment steps, unclear stitching transitions, and assumptions about prior knowledge. These are legitimate domain‑specific gaps. The model did not misinterpret the craft terminology. The output shows the model can detect specialized ambiguity patterns without finetuning. Prompt‑based domain detection works.

# %%
# Import library
import os
from openai import OpenAI

# Set API key
os.environ["OPENAI_API_KEY"] = "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"

# build openai prompt
client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])

prompt = """
Compare the following two instruction sets. Identify gap categories such as missing microsteps,
unclear transitions, unstated assumptions, missing tool requirements, or domain-specific ambiguity.

Instruction Set A: Flat Tire
(0) Stop at the road side and put a triangular warning sign to warn cars about stopping.
(1) Locate spare tyres and make sure it is inflated.
(2) Engage parking break and place vehicle in correct gear.
(3) Loosen lug nuts.
(4) Jack up car.
(5) Remove lug nuts.
(6) Remove deflated tire.
(7) Replace with spare tire.
(8) Tighten lug nuts.
(9) Lower jack.

Instruction Set B: Moccasin Kit
1. Tie a knot in one end of one of the laces just above the tip. Match up the diamond holes
in the sole and toe plug, with the other end of the lace, sew from the outside of the sole
up through the toe plug. After pulling the knot tight pass the lace back through the diamond
hole in the sole only. Your lace should have looped the two pieces of leather together and be
in between the sole and toe plug.

2. Now pass the lace on the inside of your moccasin through the next hole in the sole and pull
tight to form a pucker between the stitches. Hold the leather in place with your thumb and sew
through the next hole in the toe plug from the outside and pull your stitch tight. Continue
around the entire toe passing the lace out through the sole and down through the toe plug,
pulling each stitch tight, until you reach the next set of diamond holes.

3. Stitch through diamond holes twice, ending back on the outside of the sole. Tie the lace in
a knot as close to the leather as possible. Trim off any excess lace.

4. Cut one lace in half and use to assemble moccasin heels. Fold the ends of the sole around as
shown and match up the appropriate set of holes. Then fold the heel flap up over the back of
the moccasin.

NOTE: Each moccasin kit is designed to fit two shoe sizes. Depending on the size that will best
fit you will determine how you will assemble the heel of the moccasin. The XS kit will make a
4/5, the S will make a 6/7, the M an 8/9 and the L will make a 10/11. To make the smaller of the
sizes for the kit, match up the round holes on either side of the moccasin heel. Or, to make the
larger size for your kit you will need to match up diamond holes on either side of the moccasin heel.

Starting with the upper right side hole, lace through to the inside of the moccasin then down to
the left side lower hole. Lace through to the back by going through the right side lower hole and
back out of the remaining upper hole. Once completed, the lacing should have an "X" on the inside.
Then tie the loose ends in a square knot and trim off the excess lace.

5. Leaving about 6" of lace, go down through the left center hole in the toe plug, then out through
the next hole. Begin lacing by folding the cuff over the edge of the moccasin sole and lining up
the holes. Lace in and out through all three layers of leather in a running stitch. When you reach
the wheel of the moccasin, overlap 4 holes for smaller sizes and 3 holes for the larger sizes.

6. Continue running stitch all the way around the moccasin and finish by threading the lace out
through the toe plug as you started and evening up the lace ends. Tie the laces in a bow and your
moccasin is complete.
"""

resp = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": prompt}]
)

print(resp.choices[0].message.content)
# Out:
# When comparing the provided instruction sets for changing a flat tire and assembling a moccasin kit, several gap categories emerge that can be analyzed for each set.
#
# ### Instruction Set A: Flat Tire
# 1. **Missing Microsteps**:
#    - The instruction for "Loosen lug nuts" doesn't specify whether to loosen them while the tire is on the ground or after raising the vehicle.
#    - There is no detailed method for how to use the jack or which type of jack is being used (e.g., scissor jack vs. hydraulic jack).
#
# 2. **Unclear Transitions**:
#    - The transition from "Jack up car" to "Remove lug nuts" could be clearer. An indication that the lug nuts must be fully loosened before using the jack or confirming the car is securely raised would improve clarity.
#
# 3. **Unstated Assumptions**:
#    - Assumes that the user knows how to operate a jack effectively and safely.
#    - Assumes that the user has already gathered the necessary tools (jack, lug wrench, spare tire).
#
# 4. **Missing Tool Requirements**:
#    - There is no specific mention of the tools needed (e.g., jack, lug wrench, possibly a tire pressure gauge to check the spare tire).
#
# 5. **Domain-Specific Ambiguity**:
#    - The term "parking break" may vary in naming (parking brake, handbrake), which could create confusion.
#
# ### Instruction Set B: Moccasin Kit
# 1. **Missing Microsteps**:
#    - Certain steps are complex and could break down further; for instance, the “sew through the next hole” instruction could include specific guiding tips for beginners, such as how to position the lace or hold the materials.
#    - Instructions such as matching holes for size could provide visual aids for clarity.
#
# 2. **Unclear Transitions**:
#    - The transitions between different lacing techniques are abrupt. More guidance or references to previous steps would help connect the instructions logically, ensuring the reader understands which method to employ next.
#    - The transition from cutting the lace to using it for heel assembly could be more seamless with a preparatory note.
#
# 3. **Unstated Assumptions**:
#    - It assumes the reader has basic sewing skills. Instructions regarding basic sewing techniques (e.g., tying knots, making tight stitches) should be included for clarity.
#    - Assumes that the reader is familiar with the concept of "diamond holes" without defining or illustrating this term.
#
# 4. **Missing Tool Requirements**:
#    - There is no mention of necessary tools (e.g., scissors, needles, and measuring instruments) for the assembly process.
#
# 5. **Domain-Specific Ambiguity**:
#    - Describing sizes such as “XS,” “S,” etc. might not be clear for users unfamiliar with these sizing conventions. A clearer reference to standard size charts could enhance usability.
#
# ### Overall Comparison
#
# Both sets could benefit from marked improvements in clarity and detail. The flat tire set is more pragmatic in guiding the user through a critical safety task but lacks granular steps that would be beneficial for novices. The moccasin kit set is more detailed but perhaps assumes a level of sewing knowledge that not all users may have.
#
# In summary:
# - **Instruction Set A** needs more information on tools, clearer steps, and safe operation methods.
# - **Instruction Set B** requires simpler language, illustrations for complex steps, and basic assumptions addressed regarding sewing skills and tool usage.
#
# Addressing these gaps could significantly enhance both instruction sets, providing more comprehensive guidance and improving user safety and success.

# %% [markdown]
# #### Experiment 5 Commentary – Comparative Gap Detection (Both Sets)
# The model compared both instruction sets and classified gaps into categories: missing microsteps, unclear transitions, unstated assumptions, missing tools, and domain‑specific ambiguity. The model generalized across unrelated domains without losing context. This confirms that the model can categorize gaps consistently using prompt‑based methods.

# %% [markdown]
# ### Final Evaluation Commentary
# Across all five experiments, the model consistently detected gaps, classified ambiguity, and produced structured outputs. The model did not hallucinate, misinterpret domain terminology, or produce inconsistent results. Prompt‑based methods are sufficient for detecting and correcting instruction gaps. Fine‑tuning is not required at this stage. It remains optional for future milestones if higher consistency or domain specialization becomes necessary.
